# %%
s = "The Geek King"
l,u = 0,0
for i in s:
    if (i>='a'and i<='z'):
        l=l+1                 
    if (i>='A'and i<='Z'):
        u=u+1   
          
print('Lower case characters: ',l)
print('Upper case characters: ',u)








def multiplyList(myList) :
    result = 1
    for x in myList:
         result = result * x
    return result
list1 = [1, 2, 3]
list2 = [3, 2, 4]
print(multiplyList(list1))
print(multiplyList(list2))









import numpy as np
import math
def bacteriaGrowth(bac_count, growth_rate, capacity, max_size):
    time = 0
    while max_size < bac_count:
        time = time + 1
        bac_count = (1 + growth_rate * (1 - bac_count/capacity)) 
    return time
 
bac_count = input("Initial Bacterial count")
growth_rate = input("And So On")
 
print(bacteriaGrowth(bac_count, growth_rate, capacity, max_size))













a=['a', 'b', 'c', 'd']
def reverse(a):
    return[ele for ele in reversed(a)]
print(reverse(a))










list1 = [11, 5, 17, 18, 23]
def sumOfList(list, size):
    if (size == 0):
        return 0
    else:
        return list[size - 1] + sumOfList(list, size - 1)
      
total = sumOfList(list1, len(list1))
 
print("Sum of all elements in given list: ", total)








def Remove(duplicate):
    final_list = []
    for num in duplicate:
        if num not in final_list:
            final_list.append(num)
    return final_list
     
duplicate = [1, 4, 12, 20, 12, 2, 20, 4]
print(Remove(duplicate))






def maximum(a, b, c):
  
    if (a >= b) and (a >= c):
        largest = a
  
    elif (b >= a) and (b >= c):
        largest = b
    else:
        largest = c
          
    return largest
  
a = 20
b = 24
c = 9
print(maximum(a, b, c))
# Out:
# Lower case characters:  8
# Upper case characters:  3
# 6
# 24
